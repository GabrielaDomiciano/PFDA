# %% [markdown]
# Gabriela Domiciano

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = ['Categoria 1', 'Categoria 2', 'Categoria 3']
y = [10, 20, 15]

# %%
fig, ax = plt.subplots()
ax.bar(x, y)

ax.set_title("yo mama")
ax.set_xlabel("x here")
ax.set_ylabel("y here")


plt.show()
